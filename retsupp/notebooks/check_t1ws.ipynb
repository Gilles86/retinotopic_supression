# %%
from nilearn import image

# %%
imp = image.load_img('/data/ds-retsupp/derivatives/fmriprep/sub-02/ses-1/anat/sub-02_ses-1_desc-preproc_T1w.nii.gz')
imo = image.load_img('/data/ds-retsupp/sub-02/ses-1/anat/sub-02_ses-1_T1w.nii.gz')

# %%
import seaborn as sns

sns.scatterplot(x=imo.get_fdata().ravel(), y=imp.get_fdata().ravel(), alpha=0.1)
# Out:
# <Axes: >
